# %%
import pandas as pd
from helpers import *
# %matplotlib inline

# %% [markdown]
# ## Primer estudio
# Input: eppyProject/input/simple_room_1_window_1_door.idf
#
# with obj ['PEOPLE', 'LIGHTS', 'ELECTRICEQUIPMENT'] deleted (no lights, people or electricequipment)
#
# Variables: ['Site Outdoor Air Drybulb Temperature','Zone Air Temperature']
#
# python Script: TemperaturaStudy.py

# %%
data = eso_to_ts('output/no_HVC_no_people_study/eplusout.csv')

# %%
data.head()
# Out:
#                      Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)  \
# Date/Time
# 2000-01-01 01:00:00                                          -4.666667
# 2000-01-01 02:00:00                                          -3.000000
# 2000-01-01 03:00:00                                          -3.583333
# 2000-01-01 04:00:00                                          -2.833333
# 2000-01-01 05:00:00                                          -2.000000
#
#                      THERMAL ZONE 1 THERMAL ZONE:Zone Air Temperature [C](Hourly)
# Date/Time
# 2000-01-01 01:00:00                                          10.327779
# 2000-01-01 02:00:00                                          10.459676
# 2000-01-01 03:00:00                                          10.301047
# 2000-01-01 04:00:00                                          10.218339
# 2000-01-01 05:00:00                                          10.265107

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Date/Time'>

# %% [markdown]
# ## Primer estudio
#
# Input: 'eppyProject/input/simple_room_1_window_1_door_ventilator_constant.idf'.idf
#
# with obj ['PEOPLE', 'LIGHTS', 'ELECTRICEQUIPMENT'] deleted (no lights, people or electricequipment)
#
# Variables: ['Site Outdoor Air Drybulb Temperature','Zone Air Temperature']
#
# python Script: TemperaturaStudy2.py
#
# HVAC Templte (...)

# %%
data2 = eso_to_ts('/home/paula/Documentos/Doctorado/Desarrollo/eppyProject/studies/Temperaturestudy2/eplusout.csv')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-f0fff37cdd12> in <module>()
# ----> 1 data2 = eso_to_ts('/home/paula/Documentos/Doctorado/Desarrollo/eppyProject/studies/Temperaturestudy2/eplusout.csv')
#
# /home/paula/Documentos/Doctorado/Desarrollo/eppyProject/helpers.py in eso_to_ts(outputfile)
#      75     df = pd.read_csv(outputfile)
#      76     if sum(df['Date/Time'].duplicated())>0:
# ---> 77         raise Exception('dates are duplicated. Impossible to convert to Time Series data frame')
#      78     else:
#      79         new = df['Date/Time'].str.split('  ', n=1, expand=True)
#
# Exception: dates are duplicated. Impossible to convert to Time Series data frame

# %%
# %%bash
# ls /home/paula/Documentos/Doctorado/Desarrollo/eppyProject/studies/Temperaturestudy2/
# Out:
# eplusout.audit
# eplusout.bnd
# eplusout.csv
# eplusout.eio
# eplusout.end
# eplusout.err
# eplusout.eso
# eplusout.expidf
# eplusout.mdd
# eplusout.mtd
# eplusout.rdd
# eplusout.shd
# eplusout.sql
# eplusssz.csv
# eplustbl.htm
# epluszsz.csv
# readvars.audit
# ReadVarsESO
# sqlite.err
